# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavyasree-Toleti/FMML-COURSE-ASSIGNMENTSS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 15:19:03--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   217MB/s    in 0.3s
#
# 2023-05-03 15:19:06 (217 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3760 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 16  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39243  1504.03834v2  We compare the capability of wavelet functions...    cs
# 38076   1208.3530v1  The New York Public Library is participating i...    cs
# 25154  1506.02106v5  The semantic image segmentation task presents ...    cs
# 22061   1409.2824v2  We present a novel, scalable and Bayesian appr...  stat
# 30662  1712.09775v2  This report presents the results of a sky dete...    cs
# ...             ...                                                ...   ...
# 24899   1412.6607v5  We study the structure of representations, def...    cs
# 12534  1802.07954v1  Visual analytics systems combine machine learn...  stat
# 26521  1610.09816v1  Gait has been considered as a promising and un...    cs
# 13166  1710.06382v2  Many iterative procedures in stochastic optimi...  stat
# 37969   1306.3627v1  Conditional independence tests (CI tests) have...  stat
#
#                                                    title  year  \
# 39243  Comparisons of wavelet functions in QRS signal...  2015
# 38076  Leveraging Subjective Human Annotation for Clu...  2012
# 25154  What's the Point: Semantic Segmentation with P...  2015
# 22061      Scalable Bayesian Modelling of Paired Symbols  2014
# 30662  Sky detection and log illumination refinement ...  2017
# ...                                                  ...   ...
# 24899  Visual Scene Representations: Contrast, Scalin...  2014
# 12534  The State of the Art in Integrating Machine Le...  2018
# 26521  Robust Gait Recognition by Integrating Inertia...  2016
# 13166  Convergence diagnostics for stochastic gradien...  2017
# 37969  Bayesian test of significance for conditional ...  2013
#
#                                                 keywords
# 39243  [capability, functions, preprocessing, detecti...
# 38076  [participating, chronicling, initiative, searc...
# 25154  [segmentation, annotation, annotations, consum...
# 22061  [modelling, occurrence, vocabulary, generated,...
# 30662  [detection, technique, performance, previously...
# ...                                                  ...
# 24899  [structure, representations, approximations, s...
# 12534  [analytics, techniques, interactive, visualiza...
# 26521  [considered, promising, biometric, identificat...
# 13166  [iterative, procedures, stochastic, optimizati...
# 37969  [conditional, independence, attention, computa...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39243    [capability, functions, preprocessing, detecti...
# 38076    [participating, chronicling, initiative, searc...
# 25154    [segmentation, annotation, annotations, consum...
# 22061    [modelling, occurrence, vocabulary, generated,...
# 30662    [detection, technique, performance, previously...
#                                ...
# 27015    [retrieval, unsupervised, clustering, informat...
# 39674    [remarkable, optimized, unprecedented, remarka...
# 7293     [graphical, estimating, relationship, structur...
# 21902    [processes, probability, distributions, functi...
# 26452    [framework, contribution, substring, extractio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8922 words.
# Out of those 4579 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d9fc3e6b-a58e-49a6-8005-2d9d50cfa75b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9fc3e6b-a58e-49a6-8005-2d9d50cfa75b")) {                    Plotly.newPlot(                        "d9fc3e6b-a58e-49a6-8005-2d9d50cfa75b",                        [{"x":["enhancement","electrocardiogram","threshold","detection","computational","algorithm","amplitude","comparisons","arrhythmia","publications","reduction","evaluated","functions","capability","complexity","preprocessing","recognition","agreement","searchable","impossible","automatic","direction","unanimous","implementation","algorithms","developed","leveraging","annotation","automated","editorial","character","techniques","successful","annotations","newspapers","supervised","consuming","categorization","retrieval","regarding","historically","significant","researchers","consequently","designing","frequently","subjective","clustering","initiative","participating","historians","constrained","newspaper","categorized","rudimentary","providing","categories","currently","understand","unsupervised","resolution","extremely","integrated","magnitude","segmentation","benchmark","supervision","potential","incorporate","demonstrate","experimental","annotators","improvement","objectness","variational","censoring","occurrence","vocabulary","preference","procedure","popularity","generated","presented","inference","selection","modelling","principle","independent","surpasses","additionally","alternative","previously","illumination","refinement","calibration","homogeneous","performance","differential","literature","visibility","consistent","technique","positioning","situation","encounter","education","management","documents","unstructured","adjustments","representing","statistical","morphologically","inflected","determining","recommends","intelligence","candidates","constructing","application","linguistic","approaches","difficulties","including","described","significantly","languages","different","graphical","knowledge","baselines","extension","extraction","visualisation","categorical","efficient","combination","demonstrates","publication","nonparametric","considers","available","organised","additional","dependent","estimators","applications","successes","representations","convolutional","factoring","evaluation","represents","reinforcement","advantage","architecture","generalize","underlying","architectures","outperform","conventional","dimensional","commercial","reconstruction","preliminary","determine","objective","scenarios","information","construction","processing","assessing","visualizations","furthermore","conveniently","generation","functional","requiring","continuous","carefully","misclassifications","adversarial","adversarially","introduces","constraints","differentiable","construct","robustness","manipulated","mechanisms","translate","effective","instances","classification","feasibility","condition","distillation","appearance","promising","perturbations"],"y":[34,3,45,361,297,818,6,31,3,11,100,132,202,47,218,21,398,16,2,13,178,64,2,139,604,186,45,67,95,2,60,371,84,60,2,201,43,23,105,46,4,248,72,25,44,24,22,161,7,3,3,81,3,7,3,106,80,52,64,144,114,58,46,53,205,195,55,157,47,572,379,13,140,2,48,2,24,30,24,100,20,181,182,208,161,39,57,141,8,55,101,92,37,32,23,18,908,31,125,5,77,239,6,31,7,10,48,80,15,2,58,165,5,3,34,2,90,27,37,252,75,463,35,259,67,278,115,723,60,346,49,90,135,3,13,404,135,47,9,19,28,309,2,110,64,20,458,10,202,390,1,235,44,129,90,277,55,134,143,84,111,178,25,102,55,73,153,85,702,68,309,14,7,151,3,147,37,42,86,27,3,96,6,74,136,26,90,95,9,50,11,263,100,538,16,45,6,87,125,15],"type":"bar"},{"x":["enhancement","electrocardiogram","threshold","detection","computational","algorithm","amplit ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4579,), (4579, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Parameterised</span> <span style='background-color:rgba(0, 255, 0, 0.320754716981132);'>Hierarchy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Argumentation</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>Semantics</span> <span style=''>for</span> <span style=''>Extended</span> <span style=''>Logic</span> <span style='background-color:rgba(0, 255, 0, 0.4715025906735752);'>Programming</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Well</span> <span style=''>founded</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>Semantics</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 1.0);'>Argumentation</span> <span style=''>has</span> <span style=''>proved</span> <span style=''>a</span> <span style=''>useful</span> <span style=''>tool</span> <span style=''>in</span> <span style=''>defining</span> <span style=''>formal</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>semantics</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.7702702702702703);'>reasoning</span> <span style=''>by</span> <span style=''>viewing</span> <span style=''>a</span> <span style=''>proof</span> <span style=''>as</span> <span style=''>a</span> <span style=''>process</span> <span style=''>in</span> <span style=''>which</span> <span style=''>proponents</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>opponents</span> <span style=''>attack</span> <span style=''>each</span> <span style=''>others</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>arguments</span> <span style=''>by</span> <span style=''>undercuts</span> <span style=''>(attack</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>arguments</span> <span style=''>premise)</span> <span style=''>and</span> <span style=''>rebuts</span> <span style=''>(attack</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5833333333333335);'>arguments</span> <span style=''>conclusion)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>notions</span> <span style=''>of</span> <span style=''>attack</span> <span style=''>for</span> <span style=''>extended</span> <span style=''>logic</span> <span style=''>programs</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3220338983050847);'>combinations</span> <span style=''>of</span> <span style=''>undercuts</span> <span style=''>and</span> <span style=''>rebuts</span> <span style=''>and</span> <span style=''>define</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.320754716981132);'>hierarchy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>argumentation</span> <span style='background-color:rgba(0, 255, 0, 0.941747572815534);'>semantics</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>parameterised</span> <span style=''>by</span> <span style=''>the</span> <span style=''>notions</span> <span style=''>of</span> <span style=''>attack</span> <span style=''>chosen</span> <span style=''>by</span> <span style=''>proponent</span> <span style=''>and</span> <span style=''>opponent</span> <span style=''>We</span> <span style=''>prove</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>Inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Weighting</span> <span style=''>with</span> <span style=''>Survival</span> <span style=''>Outcomes</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>weighted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>survival</span> <span style=''>analysis</span> <span style=''>under</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informative</span> <span style=''>right</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>censoring</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>has</span> <span style=''>the</span> <span style=''>novel</span> <span style=''>property</span> <span style=''>that</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>a</span> <span style=''>normal</span> <span style=''>variable</span> <span style=''>at</span> <span style=''>n12</span> <span style=''>rate</span> <span style=''>for</span> <span style=''>a</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>censoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>many</span> <span style=''>data</span> <span style=''>adaptive</span> <span style=''>(eg</span> <span style=''>machine</span> <span style=''>learning)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style=''>formula</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>correct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intervals</span> <span style=''>and</span> <span style=''>p</span> <span style=''>values</span> <span style=''>under</span> <span style=''>data</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>censoring</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Edge</span> <span style='background-color:rgba(0, 255, 0, 0.4157303370786517);'>Preserving</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Denoising</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.6774193548387097);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Spaces</span> <br/><br/><span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3828571428571429);'>development</span> <span style=''>of</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>Noise</span> <span style=''>Removal</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6774193548387097);'>Reproducing</span> <span style=''>Kernels</span> <span style=''>Hilbert</span> <span style=''>Spaces</span> <span style=''>(RKHS)</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>cast</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>task</span> <span style=''>in</span> <span style=''>a</span> <span style=''>RKHS</span> <span style=''>by</span> <span style=''>taking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>celebrated</span> <span style='background-color:rgba(255, 0, 0, 0.7333333333333334);'>semiparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representer</span> <span style=''>Theorem</span> <span style=''>Examples</span> <span style=''>verify</span> <span style=''>that</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>gaussian</span> <span style=''>noise</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>performs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>well</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>wavelet</span> <span style=''>based</span> <span style=''>technics</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperforms</span> <span style=''>them</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>impulse</span> <span style=''>or</span> <span style=''>mixed</span> <span style=''>noise</span> <span style=''>A</span> <span style=''>more</span> <span style=''>detailed</span> <span style=''>version</span> <span style=''>of</span> <span style=''>this</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>published</span> <span style=''>in</span> <span style=''>the</span> <span style=''>IEEE</span> <span style=''>Trans</span> <span style=''>Im</span> <span style=''>Proc</span> <span style=''>P</span> <span style=''>Bouboulis</span> <span style=''>K</span> <span style=''>Slavakis</span> <span style=''>and</span> <span style=''>S</span> <span style=''>Theodoridis</span> <span style=''>Adaptive</span> <span style=''>Kernel</span> <span style=''>based</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Denoising</span> <span style='background-color:rgba(0, 255, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Narrow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>Machines</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximators</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>deep</span> <span style=''>narrow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>machines</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximators</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activities</span> <span style=''>of</span> <span style=''>their</span> <span style=''>visible</span> <span style=''>units</span> <span style=''>provided</span> <span style=''>they</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style=''>many</span> <span style=''>hidden</span> <span style=''>layers</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style=''>the</span> <span style=''>same</span> <span style=''>number</span> <span style=''>of</span> <span style=''>units</span> <span style=''>as</span> <span style=''>the</span> <span style=''>visible</span> <span style=''>layer</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>within</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>domains</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>machines</span> <span style=''>can</span> <span style=''>be</span> <span style=''>studied</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>feedforward</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>upper</span> <span style=''>and</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>depth</span> <span style=''>and</span> <span style=''>width</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximators</span> <span style=''>These</span> <span style=''>results</span> <span style=''>settle</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>they</span> <span style=''>show</span> <span style=''>that</span> <span style=''>deep</span> <span style=''>narrow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>machines</span> <span style=''>are</span> <span style=''>at</span> <span style=''>least</span> <span style=''>as</span> <span style=''>compact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximators</span> <span style=''>as</span> <span style=''>narrow</span> <span style=''>sigmoid</span> <span style=''>belief</span> <span style=''>networks</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1347316032705297)
# 	challenging (0.09704941343761109)
# 	processing (0.10984713828652684)
# 	segmentation (0.0728759331674369)
# 	information (0.2495556345538571)
# 	different (0.25702097404905794)
# 	architecture (0.0984713828652684)
# 	detection (0.1283327408460718)
# 	convolutional (0.13864201919658728)
# 	recognition (0.1414859580519019)
#
# Some Statistics words are:
# 	stochastic (0.1389028686462003)
# 	algorithm (0.38198288877705083)
# 	statistical (0.15349773527931554)
# 	variables (0.14292903875188726)
# 	distribution (0.17614494212380474)
# 	theoretical (0.159536990437846)
# 	estimation (0.1852038248616004)
# 	dimensional (0.17966784096628083)
# 	inference (0.20885757423251133)
# 	regression (0.18621036738802216)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="065f00e9-9187-43ae-83cf-f9f77ecb7d80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("065f00e9-9187-43ae-83cf-f9f77ecb7d80")) {                    Plotly.newPlot(                        "065f00e9-9187-43ae-83cf-f9f77ecb7d80",                        [{"x":["enhancement","electrocardiogram","threshold","detection","computational","algorithm","amplitude","comparisons","arrhythmia","publications","reduction","evaluated","functions","capability","complexity","preprocessing","recognition","agreement","searchable","impossible","automatic","direction","unanimous","implementation","algorithms","developed","leveraging","annotation","automated","editorial","character","techniques","successful","annotations","newspapers","supervised","consuming","categorization","retrieval","regarding","historically","significant","researchers","consequently","designing","frequently","subjective","clustering","initiative","participating","historians","constrained","newspaper","categorized","rudimentary","providing","categories","currently","understand","unsupervised","resolution","extremely","integrated","magnitude","segmentation","benchmark","supervision","potential","incorporate","demonstrate","experimental","annotators","improvement","objectness","variational","censoring","occurrence","vocabulary","preference","procedure","popularity","generated","presented","inference","selection","modelling","principle","independent","surpasses","additionally","alternative","previously","illumination","refinement","calibration","homogeneous","performance","differential","literature","visibility","consistent","technique","positioning","situation","encounter","education","management","documents","unstructured","adjustments","representing","statistical","morphologically","inflected","determining","recommends","intelligence","candidates","constructing","application","linguistic","approaches","difficulties","including","described","significantly","languages","different","graphical","knowledge","baselines","extension","extraction","visualisation","categorical","efficient","combination","demonstrates","publication","nonparametric","considers","available","organised","additional","dependent","estimators","applications","successes","representations","convolutional","factoring","evaluation","represents","reinforcement","advantage","architecture","generalize","underlying","architectures","outperform","conventional","dimensional","commercial","reconstruction","preliminary","determine","objective","scenarios","information","construction","processing","assessing","visualizations","furthermore","conveniently","generation","functional","requiring","continuous","carefully","misclassifications","adversarial","adversarially","introduces","constraints","differentiable","construct","robustness","manipulated","mechanisms","translate","effective","instances","classification","feasibility","condition","distillation","appearance","promising","perturbations","equivalent","sensitive","unchanged","defensive","leveraged","challenges","classifiers","consequences","technologies","intelligent","developments","something","awareness","importance","improving","processes","communication","multimedia","interactive","marketing","remarkable","intersection","artificial","platforms","introduced","companies","multidisciplinary","especially","parsimony","estimation","recovered","challenged","neuroscience","unfortunately","recoverability","sufficient","investigated","polynomial","counterparts","interpretative","compressed","nonlinear","regression","initially","identification","properties","identifiability","requirement","dimensionality","critically","following","restricted","viability","measurements","phenotype","asso ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	disproportionately
# 	sequentialized
# 	emphsparse
# 	therapies
# 	integrative
# 	predetermined
# 	nonstationarity
# 	forecasted
# 	prognostic
# 	transelliptical
# 	elliptical
# 	sparsistent
# 	horseshoe
# 	followers
# 	physiologic
# 	triggering
# 	newsvendor
# 	nonparanormal
# 	fluctuation
# 	periodicity
# Some words which never appear in Statistics papers:
# 	arrhythmia
# 	searchable
# 	unanimous
# 	editorial
# 	newspapers
# 	newspaper
# 	rudimentary
# 	objectness
# 	illumination
# 	visibility
# 	morphologically
# 	inflected
# 	recommends
# 	misclassifications
# 	awareness
# 	termination
# 	cooperate
# 	scripting
# 	connectionist
# 	undermined

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.057262527133205e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
